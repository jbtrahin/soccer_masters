# %%
import pandas as pd

# %%
players_2020_df = pd.read_csv('current_prem_players.csv')

# %%
players_2020_df
# Out:
#     Unnamed: 0            Unnamed: 1            Unnamed: 2 Unnamed: 3  \
# 0           Rk                Player                Nation        Pos
# 1            1   Patrick van Aanholt   Patrick-van-Aanholt     nl NED
# 2            2            Max Aarons            Max-Aarons    eng ENG
# 3            3         Tammy Abraham         Tammy-Abraham    eng ENG
# 4            4             Che Adams             Che-Adams    eng ENG
# ..         ...                   ...                   ...        ...
# 488        488        Pablo Zabaleta        Pablo-Zabaleta     ar ARG
# 489        489         Wilfried Zaha         Wilfried-Zaha     ci CIV
# 490        490  Christoph Zimmermann  Christoph-Zimmermann     de GER
# 491        491   Oleksandr Zinchenko   Oleksandr-Zinchenko     ua UKR
# 492        492            Kurt Zouma            Kurt-Zouma     fr FRA
#
#     Unnamed: 4       Unnamed: 5 Unnamed: 6 Playing Time Playing Time.1  \
# 0        Squad              Age       Born           MP         Starts
# 1           DF   Crystal Palace         28         1990             22
# 2           DF     Norwich City         19         2000             27
# 3           FW          Chelsea         21         1997             25
# 4           FW      Southampton         23         1996             22
# ..         ...              ...        ...          ...            ...
# 488         DF         West Ham         34         1985             10
# 489       MFFW   Crystal Palace         26         1992             29
# 490         DF     Norwich City         26         1993             15
# 491         DF  Manchester City         22         1996             12
# 492         DF          Chelsea         24         1994             22
#
#     Playing Time.2  ... Expected Expected.1 Expected.2 Per 90 Minutes.5  \
# 0              Min  ...       xG       npxG         xA               xG
# 1               22  ...      0.1        1.8          1              1.8
# 2               27  ...     0.04        0.5        0.5              3.5
# 3               23  ...     0.74       11.8       11.8              2.2
# 4                8  ...     0.25        1.9        1.9              0.9
# ..             ...  ...      ...        ...        ...              ...
# 488              6  ...        0        0.1        0.1              0.4
# 489             28  ...     0.21          4          4              2.4
# 490             15  ...     0.07        0.4        0.4                0
# 491             10  ...        0        0.3        0.3              0.7
# 492             19  ...        0        0.6        0.6                0
#
#     Per 90 Minutes.6 Per 90 Minutes.7 Per 90 Minutes.8 Per 90 Minutes.9  \
# 0                 xA            xG+xA             npxG          npxG+xA
# 1               0.09             0.09             0.17             0.05
# 2               0.02             0.13             0.15             0.02
# 3               0.55              0.1             0.65             0.55
# 4               0.23             0.11             0.35             0.23
# ..               ...              ...              ...              ...
# 488             0.01             0.06             0.06             0.01
# 489             0.14             0.08             0.23             0.14
# 490             0.03                0             0.03             0.03
# 491             0.03             0.07             0.11             0.03
# 492             0.03                0             0.03             0.03
#
#     Unnamed: 29 Unnamed: 30
# 0       Matches         NaN
# 1          0.14     Matches
# 2          0.15     Matches
# 3          0.65     Matches
# 4          0.35     Matches
# ..          ...         ...
# 488        0.06     Matches
# 489        0.23     Matches
# 490        0.03     Matches
# 491        0.11     Matches
# 492        0.03     Matches
#
# [493 rows x 31 columns]

# %%
player_names = list(players_2020_df['Unnamed: 1'])

# %%
player_names = player_names[1:]
