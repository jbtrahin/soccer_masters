# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
GK_17_20_df = pd.read_csv(Path('data/Clean_GK_17_20.csv'))
GK_17_20_df.head()
# Out:
#             Player Pos            Squad  MP  Starts     Min  GA  GA90  SoTA  \
# 0           Adrián  GK         West Ham  19      19  1710.0  29  1.53    95
# 1    Asmir Begović  GK      Bournemouth  38      38  3420.0  61  1.61   172
# 2    Claudio Bravo  GK  Manchester City   3       2   226.0   1  0.40     5
# 3     Jack Butland  GK       Stoke City  35      35  3150.0  61  1.74   199
# 4  Willy Caballero  GK          Chelsea   3       3   270.0   4  1.33    11
#
#    Saves  Save%   W   D   L  CS   CS%  PKatt  PKA  PKsv  PKm
# 0     68  0.705   7   6   6   6  31.6      1    1     0    0
# 1    113  0.657  11  11  16   6  15.8      4    2     1    1
# 2      4  0.800   2   0   0   1  50.0      0    0     0    0
# 3    145  0.719   7  11  17   6  17.1      5    5     0    0
# 4      7  0.636   1   1   1   1  33.3      0    0     0    0

# %%
GK_17_20_df = GK_17_20_df[GK_17_20_df['Min'] > 90]

# %%
plt.scatter(GK_17_20_df['Save%'], GK_17_20_df.GA90)
plt.xlabel('Save %')
plt.ylabel('Goals Allowed %')
plt.show()

# %%
X = GK_17_20_df.SoTA.values.reshape(-1, 1)
y = GK_17_20_df.CS

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Shot on target at')
plt.ylabel('Clean Sheets')
plt.show()

# %%
print(model.coef_)
# Out:
# [0.05877819]

# %%
X = GK_17_20_df.GA90.values.reshape(-1, 1)
y = GK_17_20_df.W

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Goals Allowed per 90 mins')
plt.ylabel('Wins')
plt.show()

# %%
print(model.coef_)
# Out:
# [-6.06185003]

# %% [markdown]
# ### Polynomial Models

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Goals Allowed vs Wins')
    plt.xlabel('Goals Allowed per 90 mins')
    plt.ylabel('Wins')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([-16.11606625])

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Goals Allowed per 90 mins vs Wins')
    plt.xlabel('Goals Allowed per 90 mins')
    plt.ylabel('Wins')
    plt.show()
    return
viz_polymonial()

# %%
# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([-132.78513214])

# %%
X = GK_17_20_df.SoTA.values.reshape(-1, 1)
y = GK_17_20_df.CS

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Shots on Target At vs Clean Sheets')
    plt.xlabel('Shot on target at')
    plt.ylabel('Clean Sheets')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([1.52248714])

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Shots on Target At vs Clean Sheets')
    plt.xlabel('Shot on target at')
    plt.ylabel('Clean Sheets')
    plt.show()
    return
viz_polymonial()

# %%
# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([0.54412086])

# %%
X = GK_17_20_df['Save%'].values.reshape(-1, 1)
y = GK_17_20_df.GA90

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Save % vs Goals Allowed Per 90')
    plt.xlabel('Save %')
    plt.ylabel('Goals Allowed per 90')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([-25.97435103])

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Save % vs Goals Allowed Per 90')
    plt.xlabel('Save %')
    plt.ylabel('Goals Allowed per 90')
    plt.show()
    return
viz_polymonial()
