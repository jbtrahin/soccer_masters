# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
GK_17_20_sum_df = pd.read_csv(Path('data/GK_17_20_sum_df.csv'))
GK_17_20_sum_df.head()
# Out:
#            Player  MP  Starts     Min  GA  SoTA  Saves   W   D   L  CS  PKatt  \
# 0  Aaron Ramsdale  27      27  2430.0  42   131     93   7   6  14   4      4
# 1          Adrián  29      27  2493.0  38   120     84  15   6   6   8      1
# 2   Alex McCarthy  61      61  5490.0  96   257    168  16  18  27  12      4
# 3         Alisson  58      58  5154.0  33   152    119  48   8   2  31      1
# 4      Angus Gunn  22      22  1980.0  43   101     60   6   6  10   5      3
#
#    PKA  PKsv  PKm
# 0    4     0    0
# 1    1     0    0
# 2    4     0    0
# 3    0     0    1
# 4    2     1    0

# %%
GK_17_20_sum_df = GK_17_20_sum_df[GK_17_20_sum_df['Min'] > 90]

# %%
plt.scatter(GK_17_20_sum_df['Saves'], GK_17_20_sum_df['GA'])
plt.xlabel('Saves')
plt.ylabel('Goals Allowed %')
plt.show()

# %%
X = GK_17_20_sum_df.SoTA.values.reshape(-1, 1)
y = GK_17_20_sum_df.CS

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Shot on target at')
plt.ylabel('Clean Sheets')
plt.show()

# %%
print(model.coef_)
# Out:
# [0.06392912]

# %%
X = GK_17_20_sum_df.GA.values.reshape(-1, 1)
y = GK_17_20_sum_df.W

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.xlabel('Goals Allowed per 90 mins')
plt.ylabel('Wins')
plt.show()

# %%
print(model.coef_)
# Out:
# [0.24374299]

# %% [markdown]
# ### Polynomial Models

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Goals Allowed vs Wins')
    plt.xlabel('Goals Allowed per 90 mins')
    plt.ylabel('Wins')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([3.09610315])

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Goals Allowed per 90 mins vs Wins')
    plt.xlabel('Goals Allowed per 90 mins')
    plt.ylabel('Wins')
    plt.show()
    return
viz_polymonial()

# %%
# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([0.77932372])

# %%
X = GK_17_20_sum_df.SoTA.values.reshape(-1, 1)
y = GK_17_20_sum_df.CS

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Shots on Target At vs Clean Sheets')
    plt.xlabel('Shot on target at')
    plt.ylabel('Clean Sheets')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([0.82893045])

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Shots on Target At vs Clean Sheets')
    plt.xlabel('Shot on target at')
    plt.ylabel('Clean Sheets')
    plt.show()
    return
viz_polymonial()

# %%
# Predicting a new result with Polymonial Regression
pol_reg.predict(poly_reg.fit_transform([[5.5]]))
# Out:
# array([-0.81653917])

# %%
X = GK_17_20_sum_df['Saves'].values.reshape(-1, 1)
y = GK_17_20_sum_df.GA

# %%
# Fitting Linear Regression to the dataset
lin_reg = LinearRegression()
lin_reg.fit(X, y)

# Visualizing the Linear Regression results
def viz_linear():
    plt.scatter(X, y, color='red')
    plt.plot(X, lin_reg.predict(X), color='blue')
    plt.title('Save % vs Goals Allowed Per 90')
    plt.xlabel('Save %')
    plt.ylabel('Goals Allowed per 90')
    plt.show()
    return
viz_linear()

# %%
# Predicting a new result with Linear Regression
lin_reg.predict([[5.5]])
# Out:
# array([6.13001424])

# %%
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('Save % vs Goals Allowed Per 90')
    plt.xlabel('Save %')
    plt.ylabel('Goals Allowed per 90')
    plt.show()
    return
viz_polymonial()
